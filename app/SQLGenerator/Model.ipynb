# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model = AutoModelForCausalLM.from_pretrained("model/content/sql_finetuned_model/")
tokenizer = AutoTokenizer.from_pretrained("/home/khadidja/Desktop/Financial_health_APIs/app/SQLGenerator/model/content/sql_finetuned_model/checkpoint-3/rng_state.pth")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 from transformers import AutoModelForCausalLM, AutoTokenizer
# ----> 3 model = AutoModelForCausalLM.from_pretrained("model/content/sql_finetuned_model/")
#       4 tokenizer = AutoTokenizer.from_pretrained("/home/khadidja/Desktop/Financial_health_APIs/app/SQLGenerator/model/content/sql_finetuned_model/checkpoint-3/rng_state.pth")
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:526, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     523 if kwargs.get("quantization_config", None) is not None:
#     524     _ = kwargs.pop("quantization_config")
# --> 526 config, kwargs = AutoConfig.from_pretrained(
#     527     pretrained_model_name_or_path,
#     528     return_unused_kwargs=True,
# ...
